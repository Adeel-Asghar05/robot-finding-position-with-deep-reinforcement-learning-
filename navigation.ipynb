# %%
#testing code 
import pybullet as p
import pybullet_data
import time
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback


# ---------------- Custom Gym Environment ----------------
class RobotEnv(gym.Env):
    def __init__(self, render=True):
        super(RobotEnv, self).__init__()
        
        self.render = render
        if self.render:
            p.connect(p.GUI)
        else:
            p.connect(p.DIRECT)

        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        p.setGravity(0, 0, -9.81)
        
        # Load environment
        self.plane = p.loadURDF("plane.urdf")
        self.robot = p.loadURDF("ryres.urdf", [0, 0, 0], useFixedBase=False,
                                flags=p.URDF_USE_SELF_COLLISION)
        
        # Wheels
        self.wheel_links = [9, 10, 12]   # tyre links
        for link in self.wheel_links:
            p.changeDynamics(self.robot, link,
                     lateralFriction=0.2,
                     spinningFriction=0.5,
                     rollingFriction=0.01)
            
        self.wheel_joints = [7, 8]   # drive joints
        self.max_force = 50.0
        self.max_speed = 20.0
        
        # ✅ Action space: [forward_speed (0..1), turn_rate (-1..1)]
        # self.action_space = spaces.Box(low=np.array([0.0, -1.0]), 
        #                                high=np.array([2.0, 1.0]),
        #                                dtype=np.float32)
        self.action_space = spaces.Discrete(3)  # 0=forward, 1=left, 2=right
        
        # Observation space
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4,), dtype=np.float32)
        
        # Episode settings
        self.max_steps = 10000
        self.current_step = 0
        self.goal_threshold = 0.05
        
        # Visual marker for goal
        self.goal_vis_id = None
        # ✅ Counters
        self.prev_dist = None 
        self.forward_count = 0
        self.left_turn_count = 0
        self.right_turn_count=0
        self.total_steps = 0

    def reset(self, seed=None, options=None):
        self.current_step = 0
        self.forward_count = 0
        self.left_turn_count = 0
        self.right_turn_count=0
        self.total_steps = 0
        # print("🔄 Counters reset.")
        # self.current_step = 0
        # Reset robot
        p.resetBasePositionAndOrientation(self.robot, [0, 0, 0.125], [0, 0, 0, 1])
        

        for i in range(p.getNumJoints(self.robot)):
            p.resetJointState(self.robot, i, 0)

        # Disable drive wheel motors
        for j in [7, 8]:  
            p.setJointMotorControl2(self.robot, j, p.VELOCITY_CONTROL,
                            targetVelocity=0, force=0)

        # Lock other joints
        for i in range(p.getNumJoints(self.robot)):
            if i not in [7, 8]:
                p.setJointMotorControl2(self.robot, i, p.VELOCITY_CONTROL,
                                targetVelocity=0, force=self.max_force)

        # Random goal
        self.goal = np.random.uniform(-3.5, 3.5, size=2)
        goal_pos = [self.goal[0], self.goal[1], 0.1]

        if self.goal_vis_id is not None:
            p.removeBody(self.goal_vis_id)

        vis_shape = p.createVisualShape(p.GEOM_SPHERE, radius=0.1, rgbaColor=[1, 0, 0, 1])
        col_shape = p.createCollisionShape(p.GEOM_SPHERE, radius=0.001)
        self.goal_vis_id = p.createMultiBody(baseMass=0,
                                            baseVisualShapeIndex=vis_shape,
                                            baseCollisionShapeIndex=col_shape,
                                            basePosition=goal_pos)
        
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        self.prev_dist = np.linalg.norm(np.array(gripper_pos[:2]) - self.goal)
        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2] - np.pi/2
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        goal_angle = np.arctan2(self.goal[1]-gripper_xy[1], self.goal[0]-gripper_xy[0])
        self.prev_heading_error = abs((goal_angle - yaw + np.pi) % (2*np.pi) - np.pi)


        return self._get_obs(), {}
    ##################################################################
    def step(self, action):
    # Map discrete actions to wheel speeds
        if action == 0:  # Forward
            left_vel = self.max_speed
            right_vel = self.max_speed
            self.forward_count += 1

        elif action == 1:  # Turn left
            left_vel = -0.5 * self.max_speed
            right_vel =  0.5 * self.max_speed
            self.left_turn_count += 1

        elif action == 2:  # Turn right
            left_vel =  0.5 * self.max_speed
            right_vel = -0.5 * self.max_speed
            self.right_turn_count += 1

    # Apply motor control
        p.setJointMotorControl2(self.robot, 7, p.VELOCITY_CONTROL,
                                targetVelocity=left_vel, force=self.max_force)
        p.setJointMotorControl2(self.robot, 8, p.VELOCITY_CONTROL,
                                targetVelocity=right_vel, force=self.max_force)

        p.stepSimulation()
        self.current_step += 1
        self.total_steps += 1

    # --- rest of your reward, obs, done logic stays same ---
        obs = self._get_obs()
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        dist_to_goal = np.linalg.norm(gripper_xy - self.goal)

        progress = self.prev_dist - dist_to_goal
        self.prev_dist = dist_to_goal

        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2] - np.pi/2   # align with -Y front
        goal_angle = np.arctan2(self.goal[1]-gripper_xy[1], self.goal[0]-gripper_xy[0])
        heading_error = abs((goal_angle - yaw + np.pi) % (2*np.pi) - np.pi)
        

        # reward = 0.0
        # reward += progress * 10.0
        # reward += np.cos(heading_error) * 0.5 
        # reward -= 0.01
        # --- Reward shaping ---
        reward = 0.0

        # Distance progress reward (main driver)
        reward += progress * 10.0  

        # Heading alignment reward (encourages facing goal)
        reward += np.cos(heading_error) * 0.5  

        # Penalize step cost slightly
        reward -= 0.045

        # ✅ Turning purposefully: only reward if it reduces heading error
        if action in [1, 2]:  # turn left or right
            if heading_error < self.prev_heading_error:  
                reward += 0.3   # good turn (aligning to goal)
            else:
                reward -= 0.3   # bad turn (misaligned more)

    #Save heading error for next step comparison
        self.prev_heading_error = heading_error

        done, truncated = False, False
        if dist_to_goal < self.goal_threshold:
            reward += 100
            done = True
            print(f"✅ Goal reached!")
            print(f"   Goal Position   = {self.goal}")
            print(f"   Gripper Position= {gripper_xy}")
            print(f"📊 Summary: Forward={self.forward_count}, Left-Turn={self.left_turn_count}, Right-Turn={self.right_turn_count} Steps={self.total_steps}")
        elif self.current_step >= self.max_steps:
            reward -= 50
            truncated = True
            print(f"⏳ Timeout. Reward={reward:.2f}")
            print(f"   Goal Position   = {self.goal}")
            print(f"   Gripper Position= {gripper_xy}")
            print(f"📊 Summary: Forward={self.forward_count}, Left-Turn={self.left_turn_count}, Right-Turn={self.right_turn_count} Steps={self.total_steps}")
    
        return obs, reward, done, truncated, {}

    def _get_obs(self):
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2]

        goal_vec = self.goal - gripper_xy
        dist = np.linalg.norm(goal_vec)
        angle = np.arctan2(goal_vec[1], goal_vec[0]) - yaw
        angle = (angle + np.pi) % (2 * np.pi) - np.pi
        
        return np.array([gripper_xy[0], gripper_xy[1], dist, angle], dtype=np.float32)

    def close(self):
        p.disconnect()


# ---------------- Callback for tracking episodes ----------------
class EpisodeTracker(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.episode_num = 0
        self.episode_reward = 0

    def _on_step(self) -> bool:
        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]
        self.episode_reward += reward

        if done:
            self.episode_num += 1
            print(f"🎯 Episode {self.episode_num} finished with reward {self.episode_reward:.2f}")
            self.episode_rewards.append(self.episode_reward)
            self.episode_reward = 0
        return True


# ---------------- Training ----------------
def train():
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")
    
    env = DummyVecEnv([lambda: RobotEnv(render=False)])
    callback = EpisodeTracker()
    
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=512,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.0,
        vf_coef=0.5,
        max_grad_norm=0.5,
        verbose=0,
        device=device,
    )
    
    model.learn(total_timesteps=5000_000, callback=callback)
    model.save("stage1_nav.zip")
    print("✅ Model saved as stage1_nav.zip")


# ---------------- Testing ----------------
def test():
    env = RobotEnv(render=True)
    model = PPO.load("stage1_nav.zip")
    
    obs, _ = env.reset()
    done, truncated = False, False
    total_reward = 0
    while not (done or truncated):
        action, _ = model.predict(obs)
        obs, reward, done, truncated, _ = env.step(action)
        total_reward += reward
        time.sleep(0.01)
    print(f"Episode finished with total reward = {total_reward:.2f}")
    env.close()


if __name__ == "__main__":
    train()
    # test()
# Out:
# Using device: cpu
# ⏳ Timeout. Reward=-49.67
#    Goal Position   = [-2.79648935  2.93000542]
#    Gripper Position= [-0.70411123 -1.57325237]
# 📊 Summary: Forward=1899, Left-Turn=1310, Right-Turn=2791 Steps=6000
# 🎯 Episode 1 finished with reward -850.39
# ⏳ Timeout. Reward=-50.85
#    Goal Position   = [-0.7489157  -2.72992241]
#    Gripper Position= [-4.54595197  1.08939197]
# 📊 Summary: Forward=2280, Left-Turn=2183, Right-Turn=1537 Steps=6000
# 🎯 Episode 2 finished with reward -1243.70
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-0.28760654  3.13893256]
#    Gripper Position= [ 2.34207708 -0.91729941]
# 📊 Summary: Forward=1657, Left-Turn=2849, Right-Turn=1494 Steps=6000
# 🎯 Episode 3 finished with reward -724.78
# ⏳ Timeout. Reward=-49.47
#    Goal Position   = [-2.2219468   1.05667523]
#    Gripper Position= [ 0.39432794 -0.50175382]
# 📊 Summary: Forward=814, Left-Turn=4524, Right-Turn=662 Steps=6000
# 🎯 Episode 4 finished with reward -851.97
# ⏳ Timeout. Reward=-50.00
#    Goal Position   = [ 2.53408024 -3.79447258]
#    Gripper Position= [ 0.24859274 -0.13832406]
# 📊 Summary: Forward=370, Left-Turn=5324, Right-Turn=306 Steps=6000
# 🎯 Episode 5 finished with reward -218.39
# ⏳ Timeout. Reward=-50.29
#    Goal Position   = [3.34960268 3.37109026]
#    Gripper Position= [-0.15935717  0.07960639]
# 📊 Summary: Forward=210, Left-Turn=5567, Right-Turn=223 Steps=6000
# 🎯 Episode 6 finished with reward -204.20
# ⏳ Timeout. Reward=-49.69
#    Goal Position   = [-3.43470348  2.69524806]
#    Gripper Position= [-2.67718134 -0.41054141]
# 📊 Summary: Forward=1105, Left-Turn=4017, Right-Turn=878 Steps=6000
# 🎯 Episode 7 finished with reward -6.15
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.82631352  2.86565259]
#    Gripper Position= [-3.03886652  2.04878381]
# 📊 Summary: Forward=1580, Left-Turn=2604, Right-Turn=1816 Steps=6000
# 🎯 Episode 8 finished with reward 2398.18
# ⏳ Timeout. Reward=-50.22
#    Goal Position   = [2.2320259  0.01892453]
#    Gripper Position= [2.36192948 0.33791938]
# 📊 Summary: Forward=1349, Left-Turn=3070, Right-Turn=1581 Steps=6000
# 🎯 Episode 9 finished with reward 37.45
# ⏳ Timeout. Reward=-49.57
#    Goal Position   = [-2.4310508  -3.73079449]
#    Gripper Position= [-3.07155423 -4.7341677 ]
# 📊 Summary: Forward=2979, Left-Turn=1815, Right-Turn=1206 Steps=6000
# 🎯 Episode 10 finished with reward 437.34
# ⏳ Timeout. Reward=-50.82
#    Goal Position   = [-3.54762706 -3.41437674]
#    Gripper Position= [-3.43087957 -3.37990907]
# 📊 Summary: Forward=2383, Left-Turn=2381, Right-Turn=1236 Steps=6000
# 🎯 Episode 11 finished with reward 820.78
# ✅ Goal reached!
#    Goal Position   = [-0.07221871  0.58735577]
#    Gripper Position= [-0.03612897  0.62102049]
# 📊 Summary: Forward=432, Left-Turn=998, Right-Turn=425 Steps=1855
# 🎯 Episode 12 finished with reward 231.92
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [2.39998379 3.21700435]
#    Gripper Position= [1.37644005 1.94390563]
# 📊 Summary: Forward=1005, Left-Turn=2611, Right-Turn=2384 Steps=6000
# 🎯 Episode 13 finished with reward 2598.29
# ✅ Goal reached!
#    Goal Position   = [-1.70546176  0.3601076 ]
#    Gripper Position= [-1.67602118  0.40032615]
# 📊 Summary: Forward=711, Left-Turn=1550, Right-Turn=661 Steps=2922
# 🎯 Episode 14 finished with reward 924.81
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.3341744   3.35743707]
#    Gripper Position= [-1.02765872  1.45523773]
# 📊 Summary: Forward=975, Left-Turn=2625, Right-Turn=2400 Steps=6000
# 🎯 Episode 15 finished with reward 2284.87
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [3.16064251 2.03393946]
#    Gripper Position= [0.77285416 0.55151374]
# 📊 Summary: Forward=437, Left-Turn=2793, Right-Turn=2770 Steps=6000
# 🎯 Episode 16 finished with reward 2659.25
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.6278201  -2.90462892]
#    Gripper Position= [-1.00149698 -1.54822652]
# 📊 Summary: Forward=529, Left-Turn=2781, Right-Turn=2690 Steps=6000
# 🎯 Episode 17 finished with reward 2691.93
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.15532109 -2.96870323]
#    Gripper Position= [-0.75988154 -0.98117692]
# 📊 Summary: Forward=286, Left-Turn=2765, Right-Turn=2949 Steps=6000
# 🎯 Episode 18 finished with reward 2501.67
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.59290075 -1.96814713]
#    Gripper Position= [-0.54362815 -1.18394422]
# 📊 Summary: Forward=375, Left-Turn=2817, Right-Turn=2808 Steps=6000
# 🎯 Episode 19 finished with reward 2532.32
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-0.61250693  0.89547098]
#    Gripper Position= [-0.32626614  0.28330922]
# 📊 Summary: Forward=138, Left-Turn=2996, Right-Turn=2866 Steps=6000
# 🎯 Episode 20 finished with reward 2528.81
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [-1.40083513 -3.24285441]
#    Gripper Position= [-0.107316   -0.72563708]
# 📊 Summary: Forward=47, Left-Turn=2805, Right-Turn=3148 Steps=6000
# 🎯 Episode 21 finished with reward 1903.84
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.55951871 -3.88591464]
#    Gripper Position= [-0.38912045 -0.85290916]
# 📊 Summary: Forward=32, Left-Turn=2825, Right-Turn=3143 Steps=6000
# 🎯 Episode 22 finished with reward 2771.57
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.66965464 -0.10155751]
#    Gripper Position= [-0.53481912 -0.11878722]
# 📊 Summary: Forward=28, Left-Turn=3249, Right-Turn=2723 Steps=6000
# 🎯 Episode 23 finished with reward 2382.55
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.89628984 -0.01873486]
#    Gripper Position= [-0.50392483 -0.05152646]
# 📊 Summary: Forward=25, Left-Turn=3222, Right-Turn=2753 Steps=6000
# 🎯 Episode 24 finished with reward 2317.68
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.38113615 -3.46335203]
#    Gripper Position= [-0.10210851 -0.53402712]
# 📊 Summary: Forward=14, Left-Turn=2842, Right-Turn=3144 Steps=6000
# 🎯 Episode 25 finished with reward 2641.30
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [3.90735216 2.16578318]
#    Gripper Position= [0.50987431 0.18541308]
# 📊 Summary: Forward=6, Left-Turn=3017, Right-Turn=2977 Steps=6000
# 🎯 Episode 26 finished with reward 2679.56
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [0.83578654 3.74426845]
#    Gripper Position= [0.20927621 0.44537611]
# 📊 Summary: Forward=14, Left-Turn=3012, Right-Turn=2974 Steps=6000
# 🎯 Episode 27 finished with reward 2671.98
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 3.40373533 -3.67349685]
#    Gripper Position= [ 0.30472038 -0.5712496 ]
# 📊 Summary: Forward=14, Left-Turn=2993, Right-Turn=2993 Steps=6000
# 🎯 Episode 28 finished with reward 2795.22
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.23761968 -2.31749464]
#    Gripper Position= [-0.52432683 -0.78521141]
# 📊 Summary: Forward=10, Left-Turn=2865, Right-Turn=3125 Steps=6000
# 🎯 Episode 29 finished with reward 2610.48
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.45246458  3.11518525]
#    Gripper Position= [-0.38103031  0.33692039]
# 📊 Summary: Forward=17, Left-Turn=3090, Right-Turn=2893 Steps=6000
# 🎯 Episode 30 finished with reward 2506.20
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [2.94797273 2.94334072]
#    Gripper Position= [0.59682836 0.46085701]
# 📊 Summary: Forward=29, Left-Turn=3080, Right-Turn=2891 Steps=6000
# 🎯 Episode 31 finished with reward 2631.49
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.65368557 -1.64053453]
#    Gripper Position= [-0.64082317 -0.57197856]
# 📊 Summary: Forward=33, Left-Turn=2864, Right-Turn=3103 Steps=6000
# 🎯 Episode 32 finished with reward 2759.04
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.21832373 -1.33850677]
#    Gripper Position= [-0.15365247 -0.27595662]
# 📊 Summary: Forward=13, Left-Turn=2852, Right-Turn=3135 Steps=6000
# 🎯 Episode 33 finished with reward 2727.05
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [2.34656208 2.90054911]
#    Gripper Position= [0.27997739 0.04182704]
# 📊 Summary: Forward=27, Left-Turn=3100, Right-Turn=2873 Steps=6000
# 🎯 Episode 34 finished with reward 2678.87
# ⏳ Timeout. Reward=-49.60
#    Goal Position   = [-0.65925079  0.65821098]
#    Gripper Position= [-0.05948024 -0.27168959]
# 📊 Summary: Forward=9, Left-Turn=3169, Right-Turn=2822 Steps=6000
# 🎯 Episode 35 finished with reward 1989.55
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 1.19532898 -2.37476313]
#    Gripper Position= [ 0.07880434 -0.22376791]
# 📊 Summary: Forward=3, Left-Turn=2990, Right-Turn=3007 Steps=6000
# 🎯 Episode 36 finished with reward 2763.77
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 1.55936569 -2.03382949]
#    Gripper Position= [ 0.15656896 -0.32070488]
# 📊 Summary: Forward=2, Left-Turn=2974, Right-Turn=3024 Steps=6000
# 🎯 Episode 37 finished with reward 2726.61
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [1.74814043 1.05454207]
#    Gripper Position= [0.27960487 0.03066125]
# 📊 Summary: Forward=20, Left-Turn=2986, Right-Turn=2994 Steps=6000
# 🎯 Episode 38 finished with reward 2674.18
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.27321357 -1.80489519]
#    Gripper Position= [-0.74947163 -0.74947046]
# 📊 Summary: Forward=19, Left-Turn=2816, Right-Turn=3165 Steps=6000
# 🎯 Episode 39 finished with reward 2748.55
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.76688513  2.64152071]
#    Gripper Position= [-0.17079605  0.08126591]
# 📊 Summary: Forward=31, Left-Turn=3125, Right-Turn=2844 Steps=6000
# 🎯 Episode 40 finished with reward 2450.21
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [3.49394181 2.62308713]
#    Gripper Position= [0.32587488 0.13057125]
# 📊 Summary: Forward=34, Left-Turn=3053, Right-Turn=2913 Steps=6000
# 🎯 Episode 41 finished with reward 2570.33
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [2.81781601 0.3566232 ]
#    Gripper Position= [-0.05035424 -0.12617294]
# 📊 Summary: Forward=40, Left-Turn=3047, Right-Turn=2913 Steps=6000
# 🎯 Episode 42 finished with reward 2730.66
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.99782198  0.84637986]
#    Gripper Position= [-0.59887237  0.36770755]
# 📊 Summary: Forward=25, Left-Turn=3181, Right-Turn=2794 Steps=6000
# 🎯 Episode 43 finished with reward 2253.70
# ⏳ Timeout. Reward=-49.89
#    Goal Position   = [ 0.26760071 -1.48415357]
#    Gripper Position= [-0.01896676 -1.03662869]
# 📊 Summary: Forward=32, Left-Turn=2856, Right-Turn=3112 Steps=6000
# 🎯 Episode 44 finished with reward 2330.30
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [1.8407121  2.39271253]
#    Gripper Position= [0.42060526 0.29722762]
# 📊 Summary: Forward=9, Left-Turn=2986, Right-Turn=3005 Steps=6000
# 🎯 Episode 45 finished with reward 2751.62
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-0.46194816  1.97133829]
#    Gripper Position= [-0.031978   -0.46815157]
# 📊 Summary: Forward=17, Left-Turn=3197, Right-Turn=2786 Steps=6000
# 🎯 Episode 46 finished with reward 2499.38
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [2.37313526 1.97694348]
#    Gripper Position= [ 0.22326087 -0.04339943]
# 📊 Summary: Forward=17, Left-Turn=3071, Right-Turn=2912 Steps=6000
# 🎯 Episode 47 finished with reward 2694.40
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.39832711 -0.57987464]
#    Gripper Position= [ 0.04840003 -0.204485  ]
# 📊 Summary: Forward=30, Left-Turn=2890, Right-Turn=3080 Steps=6000
# 🎯 Episode 48 finished with reward 2717.10
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [0.99245816 2.61269334]
#    Gripper Position= [0.34341351 0.48575111]
# 📊 Summary: Forward=27, Left-Turn=3110, Right-Turn=2863 Steps=6000
# 🎯 Episode 49 finished with reward 2628.61
# ⏳ Timeout. Reward=-49.54
#    Goal Position   = [-2.35937938 -1.1432698 ]
#    Gripper Position= [-0.7107413  -0.56714754]
# 📊 Summary: Forward=75, Left-Turn=2834, Right-Turn=3091 Steps=6000
# 🎯 Episode 50 finished with reward 2706.58
# ⏳ Timeout. Reward=-49.88
#    Goal Position   = [2.94819219 3.54968448]
#    Gripper Position= [0.22764259 0.48746279]
# 📊 Summary: Forward=57, Left-Turn=2973, Right-Turn=2970 Steps=6000
# 🎯 Episode 51 finished with reward 2333.63
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.0247395  -0.25773812]
#    Gripper Position= [-0.53309217 -0.09726668]
# 📊 Summary: Forward=47, Left-Turn=3070, Right-Turn=2883 Steps=6000
# 🎯 Episode 52 finished with reward 2215.32
# ⏳ Timeout. Reward=-49.27
#    Goal Position   = [-3.90977237 -2.47735845]
#    Gripper Position= [-0.84328598 -1.03733772]
# 📊 Summary: Forward=45, Left-Turn=2783, Right-Turn=3172 Steps=6000
# 🎯 Episode 53 finished with reward 2458.56
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.4386301  -1.50037027]
#    Gripper Position= [-0.68524598 -0.75436527]
# 📊 Summary: Forward=76, Left-Turn=2801, Right-Turn=3123 Steps=6000
# 🎯 Episode 54 finished with reward 2675.43
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [2.29168503 0.92093439]
#    Gripper Position= [ 0.10847291 -0.11610306]
# 📊 Summary: Forward=36, Left-Turn=3021, Right-Turn=2943 Steps=6000
# 🎯 Episode 55 finished with reward 2717.95
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 2.12709518 -2.00748096]
#    Gripper Position= [ 0.5911363  -0.89341328]
# 📊 Summary: Forward=34, Left-Turn=2851, Right-Turn=3115 Steps=6000
# 🎯 Episode 56 finished with reward 2685.57
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-3.17143895 -3.05843976]
#    Gripper Position= [-0.60669434 -0.90524314]
# 📊 Summary: Forward=28, Left-Turn=2845, Right-Turn=3127 Steps=6000
# 🎯 Episode 57 finished with reward 2586.33
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [0.97697899 2.55621486]
#    Gripper Position= [0.27748594 0.22460249]
# 📊 Summary: Forward=16, Left-Turn=3011, Right-Turn=2973 Steps=6000
# 🎯 Episode 58 finished with reward 2691.12
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 2.46296832 -1.70487069]
#    Gripper Position= [ 0.26746736 -0.50567355]
# 📊 Summary: Forward=16, Left-Turn=2966, Right-Turn=3018 Steps=6000
# 🎯 Episode 59 finished with reward 2744.17
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.66461632  3.03636029]
#    Gripper Position= [-0.32402513  0.25878781]
# 📊 Summary: Forward=36, Left-Turn=3154, Right-Turn=2810 Steps=6000
# 🎯 Episode 60 finished with reward 2469.96
# ⏳ Timeout. Reward=-49.87
#    Goal Position   = [-3.00507273  3.72126692]
#    Gripper Position= [-0.24223882  0.13676249]
# 📊 Summary: Forward=46, Left-Turn=3138, Right-Turn=2816 Steps=6000
# 🎯 Episode 61 finished with reward 2358.43
# ⏳ Timeout. Reward=-49.89
#    Goal Position   = [-1.12278809 -0.62398043]
#    Gripper Position= [-0.35899358 -0.20245243]
# 📊 Summary: Forward=39, Left-Turn=2803, Right-Turn=3158 Steps=6000
# 🎯 Episode 62 finished with reward 2454.18
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [2.56214329 2.07160138]
#    Gripper Position= [0.37048355 0.12393562]
# 📊 Summary: Forward=71, Left-Turn=2924, Right-Turn=3005 Steps=6000
# 🎯 Episode 63 finished with reward 2720.14
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-3.37994396 -0.89499932]
#    Gripper Position= [-0.05009468 -0.19160462]
# 📊 Summary: Forward=59, Left-Turn=2795, Right-Turn=3146 Steps=6000
# 🎯 Episode 64 finished with reward 2692.35
# ⏳ Timeout. Reward=-49.30
#    Goal Position   = [ 0.18184833 -1.75579301]
#    Gripper Position= [-0.14914415 -1.21408561]
# 📊 Summary: Forward=16, Left-Turn=2930, Right-Turn=3054 Steps=6000
# 🎯 Episode 65 finished with reward 2304.73
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [-0.17791638 -1.68260609]
#    Gripper Position= [-0.32900546 -0.86323083]
# 📊 Summary: Forward=13, Left-Turn=2799, Right-Turn=3188 Steps=6000
# 🎯 Episode 66 finished with reward 2386.64
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [ 3.89698023 -1.85970952]
#    Gripper Position= [ 0.38743095 -0.30753984]
# 📊 Summary: Forward=25, Left-Turn=2896, Right-Turn=3079 Steps=6000
# 🎯 Episode 67 finished with reward 2656.90
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [2.55754357 2.9441078 ]
#    Gripper Position= [0.46813751 0.28960882]
# 📊 Summary: Forward=29, Left-Turn=3076, Right-Turn=2895 Steps=6000
# 🎯 Episode 68 finished with reward 2743.17
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-0.65604324 -1.76966169]
#    Gripper Position= [-0.52149442 -0.86635357]
# 📊 Summary: Forward=15, Left-Turn=2880, Right-Turn=3105 Steps=6000
# 🎯 Episode 69 finished with reward 2506.09
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [ 3.901847   -0.22382897]
#    Gripper Position= [-0.41015905 -0.198245  ]
# 📊 Summary: Forward=22, Left-Turn=3054, Right-Turn=2924 Steps=6000
# 🎯 Episode 70 finished with reward 2581.00
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [0.18805933 3.91138323]
#    Gripper Position= [0.03886526 0.26840651]
# 📊 Summary: Forward=31, Left-Turn=3041, Right-Turn=2928 Steps=6000
# 🎯 Episode 71 finished with reward 2603.87
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 1.3125338  -2.21857065]
#    Gripper Position= [ 0.25602421 -0.60239786]
# 📊 Summary: Forward=20, Left-Turn=3009, Right-Turn=2971 Steps=6000
# 🎯 Episode 72 finished with reward 2730.78
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.98766329  2.42341751]
#    Gripper Position= [-0.41247466  0.27109951]
# 📊 Summary: Forward=21, Left-Turn=3219, Right-Turn=2760 Steps=6000
# 🎯 Episode 73 finished with reward 2493.57
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.71379898  0.62692847]
#    Gripper Position= [-0.58250476  0.14086678]
# 📊 Summary: Forward=42, Left-Turn=3205, Right-Turn=2753 Steps=6000
# 🎯 Episode 74 finished with reward 2394.13
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 0.8979058 -2.2049188]
#    Gripper Position= [ 0.19497048 -0.618665  ]
# 📊 Summary: Forward=18, Left-Turn=3005, Right-Turn=2977 Steps=6000
# 🎯 Episode 75 finished with reward 2745.22
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-3.03541259 -2.90002093]
#    Gripper Position= [-0.481732   -0.62595431]
# 📊 Summary: Forward=59, Left-Turn=2808, Right-Turn=3133 Steps=6000
# 🎯 Episode 76 finished with reward 2721.69
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.53396236  1.09515877]
#    Gripper Position= [-0.86689885  0.44526924]
# 📊 Summary: Forward=41, Left-Turn=3189, Right-Turn=2770 Steps=6000
# 🎯 Episode 77 finished with reward 2408.86
# ✅ Goal reached!
#    Goal Position   = [-0.49303664 -0.75347454]
#    Gripper Position= [-0.4911473  -0.70402134]
# 📊 Summary: Forward=24, Left-Turn=1275, Right-Turn=1404 Steps=2703
# 🎯 Episode 78 finished with reward 1147.49
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 3.38895088 -0.83950613]
#    Gripper Position= [ 0.56580019 -0.35994811]
# 📊 Summary: Forward=101, Left-Turn=2943, Right-Turn=2956 Steps=6000
# 🎯 Episode 79 finished with reward 2725.92
# ⏳ Timeout. Reward=-49.89
#    Goal Position   = [ 0.72752708 -1.45441694]
#    Gripper Position= [ 0.21912049 -0.82419509]
# 📊 Summary: Forward=87, Left-Turn=2924, Right-Turn=2989 Steps=6000
# 🎯 Episode 80 finished with reward 2546.72
# ⏳ Timeout. Reward=-49.87
#    Goal Position   = [-0.68352501 -1.42364996]
#    Gripper Position= [-0.6992623  -1.25258245]
# 📊 Summary: Forward=94, Left-Turn=2963, Right-Turn=2943 Steps=6000
# 🎯 Episode 81 finished with reward 2528.75
# ⏳ Timeout. Reward=-49.56
#    Goal Position   = [3.37824135 3.90060729]
#    Gripper Position= [0.6975764 1.3113387]
# 📊 Summary: Forward=392, Left-Turn=2835, Right-Turn=2773 Steps=6000
# 🎯 Episode 82 finished with reward 2490.76
# ⏳ Timeout. Reward=-49.88
#    Goal Position   = [-3.63970143  2.94982819]
#    Gripper Position= [-1.17837526  0.45922984]
# 📊 Summary: Forward=371, Left-Turn=3139, Right-Turn=2490 Steps=6000
# 🎯 Episode 83 finished with reward 2242.25
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 1.26711138 -2.87290827]
#    Gripper Position= [ 0.26377675 -0.60324102]
# 📊 Summary: Forward=253, Left-Turn=2818, Right-Turn=2929 Steps=6000
# 🎯 Episode 84 finished with reward 2742.01
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.34157879  0.21088559]
#    Gripper Position= [-0.84961055  0.05601867]
# 📊 Summary: Forward=105, Left-Turn=3109, Right-Turn=2786 Steps=6000
# 🎯 Episode 85 finished with reward 2387.12
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 2.90529213 -2.89681496]
#    Gripper Position= [ 0.57707939 -0.82601876]
# 📊 Summary: Forward=105, Left-Turn=2861, Right-Turn=3034 Steps=6000
# 🎯 Episode 86 finished with reward 2703.70
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.17089512 -2.04790852]
#    Gripper Position= [-0.29310234 -1.18334242]
# 📊 Summary: Forward=56, Left-Turn=2880, Right-Turn=3064 Steps=6000
# 🎯 Episode 87 finished with reward 2510.39
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [1.7643243  3.11432697]
#    Gripper Position= [0.72364377 0.90684666]
# 📊 Summary: Forward=275, Left-Turn=2951, Right-Turn=2774 Steps=6000
# 🎯 Episode 88 finished with reward 2659.94
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-2.65272183  3.8495995 ]
#    Gripper Position= [-0.79774641  0.69338382]
# 📊 Summary: Forward=296, Left-Turn=3026, Right-Turn=2678 Steps=6000
# 🎯 Episode 89 finished with reward 2377.75
# ⏳ Timeout. Reward=-49.58
#    Goal Position   = [2.13834458 1.15235146]
#    Gripper Position= [0.8818439  0.31417817]
# 📊 Summary: Forward=506, Left-Turn=2672, Right-Turn=2822 Steps=6000
# 🎯 Episode 90 finished with reward 2566.73
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [3.65856925 0.94617186]
#    Gripper Position= [1.75536615 0.34232268]
# 📊 Summary: Forward=901, Left-Turn=2559, Right-Turn=2540 Steps=6000
# 🎯 Episode 91 finished with reward 2647.44
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-3.81625156 -2.75710448]
#    Gripper Position= [-1.69607989 -1.91071578]
# 📊 Summary: Forward=903, Left-Turn=2508, Right-Turn=2589 Steps=6000
# 🎯 Episode 92 finished with reward 2617.03
# ✅ Goal reached!
#    Goal Position   = [-0.1241882   0.87197163]
#    Gripper Position= [-0.08664159  0.8392791 ]
# 📊 Summary: Forward=346, Left-Turn=1224, Right-Turn=753 Steps=2323
# 🎯 Episode 93 finished with reward 862.56
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.00160339 -3.78851377]
#    Gripper Position= [-1.44218352 -2.65468125]
# 📊 Summary: Forward=749, Left-Turn=2735, Right-Turn=2516 Steps=6000
# 🎯 Episode 94 finished with reward 2774.89
# ⏳ Timeout. Reward=-49.55
#    Goal Position   = [-1.69331838  2.03069805]
#    Gripper Position= [-1.54559485  1.84015099]
# 📊 Summary: Forward=1082, Left-Turn=2603, Right-Turn=2315 Steps=6000
# 🎯 Episode 95 finished with reward 2514.27
# ⏳ Timeout. Reward=-49.93
#    Goal Position   = [ 3.94311381 -0.49286688]
#    Gripper Position= [ 2.76697239 -0.95082371]
# 📊 Summary: Forward=1027, Left-Turn=2529, Right-Turn=2444 Steps=6000
# 🎯 Episode 96 finished with reward 2437.23
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [0.37178155 2.02190446]
#    Gripper Position= [0.44831771 1.12638435]
# 📊 Summary: Forward=522, Left-Turn=2886, Right-Turn=2592 Steps=6000
# 🎯 Episode 97 finished with reward 2416.52
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.06390551 -2.38426437]
#    Gripper Position= [-0.94533488 -1.66578938]
# 📊 Summary: Forward=259, Left-Turn=2850, Right-Turn=2891 Steps=6000
# 🎯 Episode 98 finished with reward 2574.50
# ⏳ Timeout. Reward=-49.27
#    Goal Position   = [ 2.23775334 -2.34809623]
#    Gripper Position= [ 1.31628829 -1.785313  ]
# 📊 Summary: Forward=544, Left-Turn=2615, Right-Turn=2841 Steps=6000
# 🎯 Episode 99 finished with reward 2682.90
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [-3.90811099  1.44056269]
#    Gripper Position= [-2.09347894  0.2845018 ]
# 📊 Summary: Forward=854, Left-Turn=2942, Right-Turn=2204 Steps=6000
# 🎯 Episode 100 finished with reward 2287.36
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.38920452  2.78536236]
#    Gripper Position= [-0.22665599  0.74454672]
# 📊 Summary: Forward=383, Left-Turn=2839, Right-Turn=2778 Steps=6000
# 🎯 Episode 101 finished with reward 2525.72
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [ 1.73627595 -0.7373449 ]
#    Gripper Position= [ 0.71542038 -0.68546662]
# 📊 Summary: Forward=200, Left-Turn=2885, Right-Turn=2915 Steps=6000
# 🎯 Episode 102 finished with reward 2612.24
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 0.7308826  -3.48266743]
#    Gripper Position= [ 0.28395616 -1.04089332]
# 📊 Summary: Forward=156, Left-Turn=2813, Right-Turn=3031 Steps=6000
# 🎯 Episode 103 finished with reward 2693.05
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.41192778 -2.58476795]
#    Gripper Position= [-0.2907437  -1.19337063]
# 📊 Summary: Forward=69, Left-Turn=2797, Right-Turn=3134 Steps=6000
# 🎯 Episode 104 finished with reward 2568.20
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [2.09808559 3.72208216]
#    Gripper Position= [0.63708248 1.28735815]
# 📊 Summary: Forward=443, Left-Turn=2917, Right-Turn=2640 Steps=6000
# 🎯 Episode 105 finished with reward 2661.84
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [3.38262944 3.85611233]
#    Gripper Position= [0.98287333 1.27210759]
# 📊 Summary: Forward=583, Left-Turn=2890, Right-Turn=2527 Steps=6000
# 🎯 Episode 106 finished with reward 2684.93
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-3.07115363 -2.34714141]
#    Gripper Position= [-0.7423957  -0.82859475]
# 📊 Summary: Forward=202, Left-Turn=2745, Right-Turn=3053 Steps=6000
# 🎯 Episode 107 finished with reward 2731.97
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.37267863 -2.02889704]
#    Gripper Position= [-0.67095384 -0.66895668]
# 📊 Summary: Forward=121, Left-Turn=2773, Right-Turn=3106 Steps=6000
# 🎯 Episode 108 finished with reward 2724.63
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 3.59539925 -1.5996259 ]
#    Gripper Position= [ 0.42569518 -0.50691967]
# 📊 Summary: Forward=121, Left-Turn=2913, Right-Turn=2966 Steps=6000
# 🎯 Episode 109 finished with reward 2757.24
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 1.10407108 -2.44274306]
#    Gripper Position= [ 0.34420882 -0.90419121]
# 📊 Summary: Forward=81, Left-Turn=2884, Right-Turn=3035 Steps=6000
# 🎯 Episode 110 finished with reward 2781.17
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [1.40490679 2.56553815]
#    Gripper Position= [0.54072812 0.54274278]
# 📊 Summary: Forward=197, Left-Turn=3011, Right-Turn=2792 Steps=6000
# 🎯 Episode 111 finished with reward 2595.96
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-3.56465891 -3.8321084 ]
#    Gripper Position= [-0.81471602 -1.20238884]
# 📊 Summary: Forward=228, Left-Turn=2822, Right-Turn=2950 Steps=6000
# 🎯 Episode 112 finished with reward 2665.08
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [ 1.45972574 -0.21049942]
#    Gripper Position= [ 0.72343257 -0.3734118 ]
# 📊 Summary: Forward=267, Left-Turn=2787, Right-Turn=2946 Steps=6000
# 🎯 Episode 113 finished with reward 2520.21
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.77473648 -0.25145497]
#    Gripper Position= [-0.62837091 -0.21356885]
# 📊 Summary: Forward=451, Left-Turn=3048, Right-Turn=2501 Steps=6000
# 🎯 Episode 114 finished with reward 2378.01
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 2.03612582 -0.30987043]
#    Gripper Position= [ 0.94335323 -0.36300842]
# 📊 Summary: Forward=273, Left-Turn=2808, Right-Turn=2919 Steps=6000
# 🎯 Episode 115 finished with reward 2620.24
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.04195859  0.98029426]
#    Gripper Position= [-1.49951106  0.53069821]
# 📊 Summary: Forward=584, Left-Turn=3084, Right-Turn=2332 Steps=6000
# 🎯 Episode 116 finished with reward 2503.87
# ✅ Goal reached!
#    Goal Position   = [0.17066075 0.67745621]
#    Gripper Position= [0.19193189 0.63229492]
# 📊 Summary: Forward=197, Left-Turn=1833, Right-Turn=1445 Steps=3475
# 🎯 Episode 117 finished with reward 1458.08
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [0.43678867 2.25935874]
#    Gripper Position= [0.45790186 1.78161319]
# 📊 Summary: Forward=536, Left-Turn=2869, Right-Turn=2595 Steps=6000
# 🎯 Episode 118 finished with reward 2555.49
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.49194782  0.98151813]
#    Gripper Position= [-2.49007437  0.71560919]
# 📊 Summary: Forward=927, Left-Turn=3037, Right-Turn=2036 Steps=6000
# 🎯 Episode 119 finished with reward 2428.60
# ✅ Goal reached!
#    Goal Position   = [-0.47981078 -0.89031941]
#    Gripper Position= [-0.4744952 -0.8408301]
# 📊 Summary: Forward=211, Left-Turn=1280, Right-Turn=1330 Steps=2821
# 🎯 Episode 120 finished with reward 1353.17
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.08694527 -2.72857244]
#    Gripper Position= [ 0.76549414 -1.71711441]
# 📊 Summary: Forward=423, Left-Turn=2603, Right-Turn=2974 Steps=6000
# 🎯 Episode 121 finished with reward 2719.81
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 2.66589395 -0.9915997 ]
#    Gripper Position= [ 1.5238468  -0.76944919]
# 📊 Summary: Forward=554, Left-Turn=2731, Right-Turn=2715 Steps=6000
# 🎯 Episode 122 finished with reward 2737.54
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [1.09341055 1.81506193]
#    Gripper Position= [0.91646542 1.20960723]
# 📊 Summary: Forward=458, Left-Turn=2930, Right-Turn=2612 Steps=6000
# 🎯 Episode 123 finished with reward 2527.25
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.58415804  1.86737951]
#    Gripper Position= [-0.30091488  0.54904113]
# 📊 Summary: Forward=340, Left-Turn=2904, Right-Turn=2756 Steps=6000
# 🎯 Episode 124 finished with reward 2610.33
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.71882451  2.60455724]
#    Gripper Position= [-0.39193773  0.8390851 ]
# 📊 Summary: Forward=314, Left-Turn=2861, Right-Turn=2825 Steps=6000
# 🎯 Episode 125 finished with reward 2524.47
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.12265092  0.47468284]
#    Gripper Position= [-0.61017946  0.3216441 ]
# 📊 Summary: Forward=104, Left-Turn=3140, Right-Turn=2756 Steps=6000
# 🎯 Episode 126 finished with reward 2309.70
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-3.32216059  0.3257493 ]
#    Gripper Position= [-0.3749861  -0.14481589]
# 📊 Summary: Forward=161, Left-Turn=3130, Right-Turn=2709 Steps=6000
# 🎯 Episode 127 finished with reward 2358.47
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.75570992 -1.06230521]
#    Gripper Position= [-0.49687106 -0.40077698]
# 📊 Summary: Forward=122, Left-Turn=2765, Right-Turn=3113 Steps=6000
# 🎯 Episode 128 finished with reward 2646.86
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [1.63468429 0.64754993]
#    Gripper Position= [0.29380907 0.06361353]
# 📊 Summary: Forward=73, Left-Turn=2989, Right-Turn=2938 Steps=6000
# 🎯 Episode 129 finished with reward 2678.79
# ⏳ Timeout. Reward=-49.54
#    Goal Position   = [1.02660204 2.51931484]
#    Gripper Position= [0.31423916 0.30695841]
# 📊 Summary: Forward=113, Left-Turn=2959, Right-Turn=2928 Steps=6000
# 🎯 Episode 130 finished with reward 2762.31
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.37288238  3.98986323]
#    Gripper Position= [-0.37106259  0.25207877]
# 📊 Summary: Forward=238, Left-Turn=3018, Right-Turn=2744 Steps=6000
# 🎯 Episode 131 finished with reward 2440.21
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-0.44657688  3.05135403]
#    Gripper Position= [-0.08167405  0.06416173]
# 📊 Summary: Forward=115, Left-Turn=3110, Right-Turn=2775 Steps=6000
# 🎯 Episode 132 finished with reward 2632.39
# ✅ Goal reached!
#    Goal Position   = [0.37497046 0.03513012]
#    Gripper Position= [0.33006953 0.01339067]
# 📊 Summary: Forward=29, Left-Turn=2374, Right-Turn=2212 Steps=4615
# 🎯 Episode 133 finished with reward 2060.36
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [3.75242481 3.93546462]
#    Gripper Position= [0.42838476 0.22745629]
# 📊 Summary: Forward=90, Left-Turn=2955, Right-Turn=2955 Steps=6000
# 🎯 Episode 134 finished with reward 2708.50
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [0.95213375 2.30104336]
#    Gripper Position= [0.34324333 0.31645122]
# 📊 Summary: Forward=30, Left-Turn=3110, Right-Turn=2860 Steps=6000
# 🎯 Episode 135 finished with reward 2581.46
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.73995482 -3.33214688]
#    Gripper Position= [-0.66724252 -1.0938166 ]
# 📊 Summary: Forward=48, Left-Turn=2922, Right-Turn=3030 Steps=6000
# 🎯 Episode 136 finished with reward 2720.23
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 1.04902344 -0.09222544]
#    Gripper Position= [-0.02177934 -0.17687063]
# 📊 Summary: Forward=12, Left-Turn=3004, Right-Turn=2984 Steps=6000
# 🎯 Episode 137 finished with reward 2656.08
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-0.4537416   3.96152338]
#    Gripper Position= [-0.12953954 -0.00726976]
# 📊 Summary: Forward=26, Left-Turn=3175, Right-Turn=2799 Steps=6000
# 🎯 Episode 138 finished with reward 2472.44
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 3.34147336 -3.14579012]
#    Gripper Position= [ 0.18408819 -0.46709384]
# 📊 Summary: Forward=8, Left-Turn=3001, Right-Turn=2991 Steps=6000
# 🎯 Episode 139 finished with reward 2658.09
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 3.73421863 -0.98561269]
#    Gripper Position= [ 0.32743193 -0.34942715]
# 📊 Summary: Forward=7, Left-Turn=2970, Right-Turn=3023 Steps=6000
# 🎯 Episode 140 finished with reward 2801.32
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-3.7718778  -3.73959544]
#    Gripper Position= [-0.69916128 -0.80424994]
# 📊 Summary: Forward=14, Left-Turn=2832, Right-Turn=3154 Steps=6000
# 🎯 Episode 141 finished with reward 2805.06
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.83015873  1.2093175 ]
#    Gripper Position= [-0.42410955  0.233861  ]
# 📊 Summary: Forward=6, Left-Turn=3168, Right-Turn=2826 Steps=6000
# 🎯 Episode 142 finished with reward 2329.37
# ⏳ Timeout. Reward=-49.86
#    Goal Position   = [ 2.30410008 -0.63416249]
#    Gripper Position= [ 0.11045084 -0.28534986]
# 📊 Summary: Forward=0, Left-Turn=2978, Right-Turn=3022 Steps=6000
# 🎯 Episode 143 finished with reward 2703.33
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 1.43010097 -1.46501745]
#    Gripper Position= [ 0.19051163 -0.45906161]
# 📊 Summary: Forward=5, Left-Turn=2960, Right-Turn=3035 Steps=6000
# 🎯 Episode 144 finished with reward 2708.87
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.92277752 -1.37888544]
#    Gripper Position= [ 0.40838081 -0.59602551]
# 📊 Summary: Forward=2, Left-Turn=3003, Right-Turn=2995 Steps=6000
# 🎯 Episode 145 finished with reward 2789.97
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 0.20813508 -1.21996845]
#    Gripper Position= [ 0.0476701  -0.46282054]
# 📊 Summary: Forward=4, Left-Turn=3057, Right-Turn=2939 Steps=6000
# 🎯 Episode 146 finished with reward 2748.83
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-0.39838348 -1.99518318]
#    Gripper Position= [-0.32018026 -1.43037724]
# 📊 Summary: Forward=2, Left-Turn=2805, Right-Turn=3193 Steps=6000
# 🎯 Episode 147 finished with reward 2847.07
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [3.52681143 2.32997285]
#    Gripper Position= [ 0.25746708 -0.02384266]
# 📊 Summary: Forward=16, Left-Turn=3007, Right-Turn=2977 Steps=6000
# 🎯 Episode 148 finished with reward 2700.00
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.47033717 -3.40255142]
#    Gripper Position= [-0.21612243 -1.11114824]
# 📊 Summary: Forward=24, Left-Turn=2737, Right-Turn=3239 Steps=6000
# 🎯 Episode 149 finished with reward 2809.20
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.80283372 -3.08557062]
#    Gripper Position= [-0.48504363 -0.70156961]
# 📊 Summary: Forward=11, Left-Turn=2851, Right-Turn=3138 Steps=6000
# 🎯 Episode 150 finished with reward 2741.47
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.63724724  2.57483928]
#    Gripper Position= [-0.14303211 -0.00410886]
# 📊 Summary: Forward=8, Left-Turn=3241, Right-Turn=2751 Steps=6000
# 🎯 Episode 151 finished with reward 2642.18
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 1.98118131 -0.20988434]
#    Gripper Position= [ 0.31270229 -0.2220547 ]
# 📊 Summary: Forward=9, Left-Turn=2931, Right-Turn=3060 Steps=6000
# 🎯 Episode 152 finished with reward 2635.34
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.13654738 -0.67076129]
#    Gripper Position= [-0.15163786 -0.25563162]
# 📊 Summary: Forward=6, Left-Turn=2887, Right-Turn=3107 Steps=6000
# 🎯 Episode 153 finished with reward 2713.47
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 0.16034461 -2.9835373 ]
#    Gripper Position= [ 0.03271431 -0.75044741]
# 📊 Summary: Forward=4, Left-Turn=3010, Right-Turn=2986 Steps=6000
# 🎯 Episode 154 finished with reward 2660.27
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 3.39725927 -3.56016504]
#    Gripper Position= [ 0.43748803 -0.68306898]
# 📊 Summary: Forward=11, Left-Turn=2953, Right-Turn=3036 Steps=6000
# 🎯 Episode 155 finished with reward 2727.53
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.58442883  1.67660142]
#    Gripper Position= [-0.42874594  0.30582602]
# 📊 Summary: Forward=1, Left-Turn=3100, Right-Turn=2899 Steps=6000
# 🎯 Episode 156 finished with reward 2439.92
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 3.29766076 -2.60601466]
#    Gripper Position= [ 0.17756057 -0.40350848]
# 📊 Summary: Forward=15, Left-Turn=2967, Right-Turn=3018 Steps=6000
# 🎯 Episode 157 finished with reward 2719.59
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.96905122  0.40597017]
#    Gripper Position= [-0.63308661  0.12955066]
# 📊 Summary: Forward=11, Left-Turn=3210, Right-Turn=2779 Steps=6000
# 🎯 Episode 158 finished with reward 2378.14
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 2.00704758 -3.51772344]
#    Gripper Position= [ 0.09810049 -0.37239897]
# 📊 Summary: Forward=12, Left-Turn=2905, Right-Turn=3083 Steps=6000
# 🎯 Episode 159 finished with reward 2673.52
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 3.76592436 -2.52625227]
#    Gripper Position= [ 0.52165396 -0.69056974]
# 📊 Summary: Forward=129, Left-Turn=2890, Right-Turn=2981 Steps=6000
# 🎯 Episode 160 finished with reward 2779.28
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-3.27615481  3.90678221]
#    Gripper Position= [-1.04968917  0.95731579]
# 📊 Summary: Forward=676, Left-Turn=2811, Right-Turn=2513 Steps=6000
# 🎯 Episode 161 finished with reward 2514.81
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [2.24427273 0.98484813]
#    Gripper Position= [0.68326308 0.24793062]
# 📊 Summary: Forward=120, Left-Turn=2946, Right-Turn=2934 Steps=6000
# 🎯 Episode 162 finished with reward 2621.86
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [0.69140767 1.66879234]
#    Gripper Position= [0.3189935  0.26718892]
# 📊 Summary: Forward=63, Left-Turn=2984, Right-Turn=2953 Steps=6000
# 🎯 Episode 163 finished with reward 2506.07
# ⏳ Timeout. Reward=-49.26
#    Goal Position   = [-2.71621645 -3.87809911]
#    Gripper Position= [-1.14021791 -1.93513409]
# 📊 Summary: Forward=534, Left-Turn=2846, Right-Turn=2620 Steps=6000
# 🎯 Episode 164 finished with reward 2725.37
# ⏳ Timeout. Reward=-49.54
#    Goal Position   = [ 0.26639096 -3.46296621]
#    Gripper Position= [ 0.07824076 -1.01683525]
# 📊 Summary: Forward=424, Left-Turn=2756, Right-Turn=2820 Steps=6000
# 🎯 Episode 165 finished with reward 2752.21
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.08387906 -1.88210089]
#    Gripper Position= [-0.65775715 -1.05912471]
# 📊 Summary: Forward=41, Left-Turn=2872, Right-Turn=3087 Steps=6000
# 🎯 Episode 166 finished with reward 2726.57
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.11991375  3.08933929]
#    Gripper Position= [-0.31973544  0.3869369 ]
# 📊 Summary: Forward=265, Left-Turn=2848, Right-Turn=2887 Steps=6000
# 🎯 Episode 167 finished with reward 2491.28
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.99434679 -2.91311229]
#    Gripper Position= [-0.75097248 -1.03776247]
# 📊 Summary: Forward=150, Left-Turn=2856, Right-Turn=2994 Steps=6000
# 🎯 Episode 168 finished with reward 2825.08
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.5608831 -0.9503237]
#    Gripper Position= [-0.29632352 -0.29580094]
# 📊 Summary: Forward=100, Left-Turn=2795, Right-Turn=3105 Steps=6000
# 🎯 Episode 169 finished with reward 2743.58
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 3.21697546 -2.20612768]
#    Gripper Position= [ 0.80480146 -0.89119148]
# 📊 Summary: Forward=115, Left-Turn=2903, Right-Turn=2982 Steps=6000
# 🎯 Episode 170 finished with reward 2706.60
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 0.29720677 -3.86840585]
#    Gripper Position= [ 0.06657329 -0.8338512 ]
# 📊 Summary: Forward=86, Left-Turn=2958, Right-Turn=2956 Steps=6000
# 🎯 Episode 171 finished with reward 2712.45
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.90054449 -0.90487141]
#    Gripper Position= [-0.56865626 -0.3613426 ]
# 📊 Summary: Forward=186, Left-Turn=2823, Right-Turn=2991 Steps=6000
# 🎯 Episode 172 finished with reward 2666.50
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.93914531  2.58397114]
#    Gripper Position= [-0.26769317  0.09354841]
# 📊 Summary: Forward=135, Left-Turn=3053, Right-Turn=2812 Steps=6000
# 🎯 Episode 173 finished with reward 2495.53
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.03445791  1.82833428]
#    Gripper Position= [-0.21923028  0.08686868]
# 📊 Summary: Forward=61, Left-Turn=3088, Right-Turn=2851 Steps=6000
# 🎯 Episode 174 finished with reward 2527.93
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.24923408  2.9722804 ]
#    Gripper Position= [-0.17915913  0.06087375]
# 📊 Summary: Forward=40, Left-Turn=3142, Right-Turn=2818 Steps=6000
# 🎯 Episode 175 finished with reward 2504.43
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 2.10883341 -2.10755365]
#    Gripper Position= [ 0.18680379 -0.40745005]
# 📊 Summary: Forward=4, Left-Turn=2998, Right-Turn=2998 Steps=6000
# 🎯 Episode 176 finished with reward 2718.06
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.61165223 -2.58194848]
#    Gripper Position= [ 0.1738374  -0.45798332]
# 📊 Summary: Forward=2, Left-Turn=2932, Right-Turn=3066 Steps=6000
# 🎯 Episode 177 finished with reward 2745.00
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.20523261  0.07953863]
#    Gripper Position= [-0.71281251  0.10240513]
# 📊 Summary: Forward=2, Left-Turn=3222, Right-Turn=2776 Steps=6000
# 🎯 Episode 178 finished with reward 2253.17
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.66889825 -0.82055021]
#    Gripper Position= [-0.14503833 -0.25936842]
# 📊 Summary: Forward=2, Left-Turn=2907, Right-Turn=3091 Steps=6000
# 🎯 Episode 179 finished with reward 2715.73
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [3.64239749 2.19291874]
#    Gripper Position= [0.29263453 0.02013779]
# 📊 Summary: Forward=28, Left-Turn=2994, Right-Turn=2978 Steps=6000
# 🎯 Episode 180 finished with reward 2697.83
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.78692645  3.36756451]
#    Gripper Position= [-0.32825164  0.2356871 ]
# 📊 Summary: Forward=69, Left-Turn=3065, Right-Turn=2866 Steps=6000
# 🎯 Episode 181 finished with reward 2512.08
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [1.36462596 3.65740538]
#    Gripper Position= [0.33549342 0.40271581]
# 📊 Summary: Forward=71, Left-Turn=3062, Right-Turn=2867 Steps=6000
# 🎯 Episode 182 finished with reward 2674.85
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 2.54193676 -0.51759963]
#    Gripper Position= [ 0.35062322 -0.32724324]
# 📊 Summary: Forward=18, Left-Turn=2923, Right-Turn=3059 Steps=6000
# 🎯 Episode 183 finished with reward 2647.78
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 3.32147098 -1.69982579]
#    Gripper Position= [ 0.56135181 -0.60988844]
# 📊 Summary: Forward=7, Left-Turn=2895, Right-Turn=3098 Steps=6000
# 🎯 Episode 184 finished with reward 2716.53
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [3.83805203 3.59656085]
#    Gripper Position= [0.58437832 0.42576397]
# 📊 Summary: Forward=74, Left-Turn=3025, Right-Turn=2901 Steps=6000
# 🎯 Episode 185 finished with reward 2692.22
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.47209945  2.02125195]
#    Gripper Position= [-0.39018488  0.23975072]
# 📊 Summary: Forward=53, Left-Turn=3141, Right-Turn=2806 Steps=6000
# 🎯 Episode 186 finished with reward 2415.49
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.60045291  1.99097819]
#    Gripper Position= [-0.24072147  0.07919628]
# 📊 Summary: Forward=18, Left-Turn=3142, Right-Turn=2840 Steps=6000
# 🎯 Episode 187 finished with reward 2493.33
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.66536    -3.10030696]
#    Gripper Position= [-0.5411784 -0.8219661]
# 📊 Summary: Forward=21, Left-Turn=2856, Right-Turn=3123 Steps=6000
# 🎯 Episode 188 finished with reward 2791.79
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.24458584 -1.41573302]
#    Gripper Position= [-0.63955791 -0.78423837]
# 📊 Summary: Forward=5, Left-Turn=2858, Right-Turn=3137 Steps=6000
# 🎯 Episode 189 finished with reward 2692.95
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 0.20387003 -1.70137504]
#    Gripper Position= [ 0.0240082  -0.41614829]
# 📊 Summary: Forward=1, Left-Turn=3037, Right-Turn=2962 Steps=6000
# 🎯 Episode 190 finished with reward 2755.37
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.14481748 -0.28602203]
#    Gripper Position= [ 0.3417972  -0.24811017]
# 📊 Summary: Forward=4, Left-Turn=2971, Right-Turn=3025 Steps=6000
# 🎯 Episode 191 finished with reward 2666.71
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.04720204 -1.75091818]
#    Gripper Position= [-0.67623167 -0.78290335]
# 📊 Summary: Forward=4, Left-Turn=2841, Right-Turn=3155 Steps=6000
# 🎯 Episode 192 finished with reward 2733.18
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [3.47598647 2.92354806]
#    Gripper Position= [0.58966639 0.40044947]
# 📊 Summary: Forward=42, Left-Turn=3016, Right-Turn=2942 Steps=6000
# 🎯 Episode 193 finished with reward 2675.16
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-2.10037086 -0.36812938]
#    Gripper Position= [-0.34743522 -0.23815957]
# 📊 Summary: Forward=3, Left-Turn=3282, Right-Turn=2715 Steps=6000
# 🎯 Episode 194 finished with reward 2331.60
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 2.5733934  -0.08140545]
#    Gripper Position= [ 0.28746571 -0.1586698 ]
# 📊 Summary: Forward=13, Left-Turn=3075, Right-Turn=2912 Steps=6000
# 🎯 Episode 195 finished with reward 2746.77
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.89403536  2.71452414]
#    Gripper Position= [-0.15507469  0.03811861]
# 📊 Summary: Forward=31, Left-Turn=3137, Right-Turn=2832 Steps=6000
# 🎯 Episode 196 finished with reward 2547.72
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.80699479  2.2028534 ]
#    Gripper Position= [-0.39884874  0.28497428]
# 📊 Summary: Forward=11, Left-Turn=3179, Right-Turn=2810 Steps=6000
# 🎯 Episode 197 finished with reward 2483.48
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-1.31246138 -1.10149165]
#    Gripper Position= [-0.18765225 -0.2927533 ]
# 📊 Summary: Forward=1, Left-Turn=2805, Right-Turn=3194 Steps=6000
# 🎯 Episode 198 finished with reward 2675.33
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 3.0129244  -2.39567744]
#    Gripper Position= [ 0.46573155 -0.68318278]
# 📊 Summary: Forward=3, Left-Turn=2999, Right-Turn=2998 Steps=6000
# 🎯 Episode 199 finished with reward 2713.41
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.30115294  0.95716078]
#    Gripper Position= [-0.72854579  0.3725021 ]
# 📊 Summary: Forward=0, Left-Turn=3246, Right-Turn=2754 Steps=6000
# 🎯 Episode 200 finished with reward 2382.80
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-3.56882169  3.73849328]
#    Gripper Position= [-0.39155787  0.28740407]
# 📊 Summary: Forward=123, Left-Turn=3077, Right-Turn=2800 Steps=6000
# 🎯 Episode 201 finished with reward 2493.45
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.97941326  2.68649732]
#    Gripper Position= [-0.26352667  0.16644675]
# 📊 Summary: Forward=46, Left-Turn=3095, Right-Turn=2859 Steps=6000
# 🎯 Episode 202 finished with reward 2490.92
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-0.20366569 -3.25470759]
#    Gripper Position= [-0.22482313 -1.09783282]
# 📊 Summary: Forward=13, Left-Turn=2802, Right-Turn=3185 Steps=6000
# 🎯 Episode 203 finished with reward 2580.23
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.22525406 -1.74965982]
#    Gripper Position= [-0.65054556 -0.87117022]
# 📊 Summary: Forward=2, Left-Turn=2853, Right-Turn=3145 Steps=6000
# 🎯 Episode 204 finished with reward 2654.46
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.77251306 -3.88080041]
#    Gripper Position= [-0.61415479 -0.84495233]
# 📊 Summary: Forward=25, Left-Turn=2865, Right-Turn=3110 Steps=6000
# 🎯 Episode 205 finished with reward 2781.73
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.67116808 -2.48168798]
#    Gripper Position= [-0.66444631 -0.91017767]
# 📊 Summary: Forward=5, Left-Turn=2845, Right-Turn=3150 Steps=6000
# 🎯 Episode 206 finished with reward 2652.67
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.32284116  0.42893101]
#    Gripper Position= [-0.72953946  0.04514033]
# 📊 Summary: Forward=3, Left-Turn=3176, Right-Turn=2821 Steps=6000
# 🎯 Episode 207 finished with reward 2483.80
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [1.23844889 1.96190373]
#    Gripper Position= [0.44954575 0.36206887]
# 📊 Summary: Forward=4, Left-Turn=3021, Right-Turn=2975 Steps=6000
# 🎯 Episode 208 finished with reward 2545.78
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.93223899 -1.12497798]
#    Gripper Position= [-0.75429939 -0.91199154]
# 📊 Summary: Forward=1, Left-Turn=2855, Right-Turn=3144 Steps=6000
# 🎯 Episode 209 finished with reward 2704.39
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [2.792411   0.98249484]
#    Gripper Position= [0.26978522 0.00795761]
# 📊 Summary: Forward=4, Left-Turn=3026, Right-Turn=2970 Steps=6000
# 🎯 Episode 210 finished with reward 2661.78
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [1.67226314 1.12129247]
#    Gripper Position= [0.34511304 0.08943842]
# 📊 Summary: Forward=1, Left-Turn=3055, Right-Turn=2944 Steps=6000
# 🎯 Episode 211 finished with reward 2713.65
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [1.0929354  2.81716581]
#    Gripper Position= [0.3007198 0.3995649]
# 📊 Summary: Forward=6, Left-Turn=3033, Right-Turn=2961 Steps=6000
# ...
# 🎯 Episode 1653 finished with reward 2733.28
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [-0.57367585  1.03219772]
#    Gripper Position= [-0.12607604 -0.04585123]
# 📊 Summary: Forward=0, Left-Turn=3135, Right-Turn=2865 Steps=6000
# 🎯 Episode 1654 finished with reward 2536.44
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.14708011  0.10413766]
#    Gripper Position= [-0.63538267 -0.06757383]
# 📊 Summary: Forward=89, Left-Turn=3065, Right-Turn=2846 Steps=6000
# 🎯 Episode 1655 finished with reward 2421.83
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-1.94745711  2.74120495]
#    Gripper Position= [-0.25258716  0.14102282]
# 📊 Summary: Forward=58, Left-Turn=3088, Right-Turn=2854 Steps=6000
# 🎯 Episode 1656 finished with reward 2523.04
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.15791195 -1.62579265]
#    Gripper Position= [ 0.27505547 -0.52795574]
# 📊 Summary: Forward=0, Left-Turn=2940, Right-Turn=3060 Steps=6000
# 🎯 Episode 1657 finished with reward 2761.47
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.12988511  2.2667379 ]
#    Gripper Position= [-0.03826798 -0.04926868]
# 📊 Summary: Forward=12, Left-Turn=3190, Right-Turn=2798 Steps=6000
# 🎯 Episode 1658 finished with reward 2597.43
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-1.25218278 -0.57291282]
#    Gripper Position= [-0.3313941  -0.32911992]
# 📊 Summary: Forward=42, Left-Turn=2828, Right-Turn=3130 Steps=6000
# 🎯 Episode 1659 finished with reward 2731.66
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.03511096  2.88159182]
#    Gripper Position= [-1.45101322  1.79718488]
# 📊 Summary: Forward=898, Left-Turn=2597, Right-Turn=2505 Steps=6000
# 🎯 Episode 1660 finished with reward 2494.43
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [2.06174162 1.54961108]
#    Gripper Position= [0.5435046  0.31714978]
# 📊 Summary: Forward=116, Left-Turn=2985, Right-Turn=2899 Steps=6000
# 🎯 Episode 1661 finished with reward 2616.96
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-0.03284438  1.48078321]
#    Gripper Position= [-0.01463817  0.09341087]
# 📊 Summary: Forward=138, Left-Turn=2963, Right-Turn=2899 Steps=6000
# 🎯 Episode 1662 finished with reward 2587.39
# ✅ Goal reached!
#    Goal Position   = [-3.24138904 -0.38771305]
#    Gripper Position= [-3.19274798 -0.39343774]
# 📊 Summary: Forward=1009, Left-Turn=552, Right-Turn=572 Steps=2133
# 🎯 Episode 1663 finished with reward 1123.62
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.72007954  0.7902726 ]
#    Gripper Position= [-0.44159495  0.34647202]
# 📊 Summary: Forward=129, Left-Turn=3059, Right-Turn=2812 Steps=6000
# 🎯 Episode 1664 finished with reward 2497.79
# ✅ Goal reached!
#    Goal Position   = [-3.303277   -3.21060983]
#    Gripper Position= [-3.25821177 -3.19365159]
# 📊 Summary: Forward=1360, Left-Turn=465, Right-Turn=285 Steps=2110
# 🎯 Episode 1665 finished with reward 1122.41
# ✅ Goal reached!
#    Goal Position   = [-0.72072057 -2.00461812]
#    Gripper Position= [-0.70321995 -1.95798427]
# 📊 Summary: Forward=459, Left-Turn=1433, Right-Turn=1274 Steps=3166
# 🎯 Episode 1666 finished with reward 1599.80
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 3.88735915 -2.59757233]
#    Gripper Position= [ 1.54669864 -1.35877616]
# 📊 Summary: Forward=523, Left-Turn=2682, Right-Turn=2795 Steps=6000
# 🎯 Episode 1667 finished with reward 2738.72
# ✅ Goal reached!
#    Goal Position   = [-1.49790358  0.62948212]
#    Gripper Position= [-1.44943513  0.617469  ]
# 📊 Summary: Forward=459, Left-Turn=3004, Right-Turn=2249 Steps=5712
# 🎯 Episode 1668 finished with reward 2480.10
# ✅ Goal reached!
#    Goal Position   = [-1.93004516 -0.88308051]
#    Gripper Position= [-1.88212277 -0.87332009]
# 📊 Summary: Forward=610, Left-Turn=649, Right-Turn=870 Steps=2129
# 🎯 Episode 1669 finished with reward 1129.60
# ✅ Goal reached!
#    Goal Position   = [-1.76192379 -1.39769945]
#    Gripper Position= [-1.71778609 -1.37547739]
# 📊 Summary: Forward=641, Left-Turn=900, Right-Turn=1013 Steps=2554
# 🎯 Episode 1670 finished with reward 1334.94
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [0.62097215 2.09052381]
#    Gripper Position= [0.37277632 0.80504704]
# 📊 Summary: Forward=152, Left-Turn=3052, Right-Turn=2796 Steps=6000
# 🎯 Episode 1671 finished with reward 2594.17
# ✅ Goal reached!
#    Goal Position   = [-1.78947626 -2.71265676]
#    Gripper Position= [-1.75917499 -2.67374411]
# 📊 Summary: Forward=967, Left-Turn=789, Right-Turn=239 Steps=1995
# 🎯 Episode 1672 finished with reward 1043.87
# ✅ Goal reached!
#    Goal Position   = [-0.14971523 -1.769098  ]
#    Gripper Position= [-0.14889182 -1.71941743]
# 📊 Summary: Forward=520, Left-Turn=1773, Right-Turn=1978 Steps=4271
# 🎯 Episode 1673 finished with reward 2113.46
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [2.29537774 2.18004298]
#    Gripper Position= [0.8681835  0.73907984]
# 📊 Summary: Forward=218, Left-Turn=3001, Right-Turn=2781 Steps=6000
# 🎯 Episode 1674 finished with reward 2673.41
# ✅ Goal reached!
#    Goal Position   = [-2.72281596  3.28798773]
#    Gripper Position= [-2.70043684  3.24452879]
# 📊 Summary: Forward=1358, Left-Turn=817, Right-Turn=455 Steps=2630
# 🎯 Episode 1675 finished with reward 1117.45
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 0.87867648 -2.12194616]
#    Gripper Position= [ 0.69771426 -1.60986757]
# 📊 Summary: Forward=371, Left-Turn=2632, Right-Turn=2997 Steps=6000
# 🎯 Episode 1676 finished with reward 2787.89
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [3.54011037 0.03746762]
#    Gripper Position= [ 1.08431506 -0.05533386]
# 📊 Summary: Forward=635, Left-Turn=2708, Right-Turn=2657 Steps=6000
# 🎯 Episode 1677 finished with reward 2703.64
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [3.69134601 2.2107247 ]
#    Gripper Position= [1.36694723 0.94047576]
# 📊 Summary: Forward=420, Left-Turn=2888, Right-Turn=2692 Steps=6000
# 🎯 Episode 1678 finished with reward 2730.80
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 3.96886602 -2.61262687]
#    Gripper Position= [ 1.98157473 -1.62340919]
# 📊 Summary: Forward=611, Left-Turn=2676, Right-Turn=2713 Steps=6000
# 🎯 Episode 1679 finished with reward 2767.27
# ✅ Goal reached!
#    Goal Position   = [-1.89664257  2.02160865]
#    Gripper Position= [-1.86553298  1.98249241]
# 📊 Summary: Forward=838, Left-Turn=1686, Right-Turn=1298 Steps=3822
# 🎯 Episode 1680 finished with reward 1675.50
# ✅ Goal reached!
#    Goal Position   = [-2.50923975 -0.15624279]
#    Gripper Position= [-2.46092305 -0.15631729]
# 📊 Summary: Forward=844, Left-Turn=1129, Right-Turn=340 Steps=2313
# 🎯 Episode 1681 finished with reward 851.70
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 1.46067956 -1.25601592]
#    Gripper Position= [ 0.64278292 -0.80361226]
# 📊 Summary: Forward=114, Left-Turn=2945, Right-Turn=2941 Steps=6000
# 🎯 Episode 1682 finished with reward 2749.30
# ✅ Goal reached!
#    Goal Position   = [-0.65773328 -1.77302797]
#    Gripper Position= [-0.64799988 -1.72457691]
# 📊 Summary: Forward=432, Left-Turn=2120, Right-Turn=2054 Steps=4606
# 🎯 Episode 1683 finished with reward 2298.31
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 0.62483777 -2.61782111]
#    Gripper Position= [ 0.25806027 -0.93923606]
# 📊 Summary: Forward=226, Left-Turn=2837, Right-Turn=2937 Steps=6000
# 🎯 Episode 1684 finished with reward 2756.99
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 3.43675022 -0.52217214]
#    Gripper Position= [ 0.68605825 -0.30368953]
# 📊 Summary: Forward=230, Left-Turn=2796, Right-Turn=2974 Steps=6000
# 🎯 Episode 1685 finished with reward 2751.88
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [1.00875834 2.63620492]
#    Gripper Position= [0.46635362 0.75412743]
# 📊 Summary: Forward=47, Left-Turn=3065, Right-Turn=2888 Steps=6000
# 🎯 Episode 1686 finished with reward 2605.30
# ✅ Goal reached!
#    Goal Position   = [-2.19208946 -3.88579991]
#    Gripper Position= [-2.16984275 -3.84143735]
# 📊 Summary: Forward=1213, Left-Turn=1645, Right-Turn=968 Steps=3826
# 🎯 Episode 1687 finished with reward 1928.19
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 0.11111228 -0.83807539]
#    Gripper Position= [ 0.10280183 -0.77618748]
# 📊 Summary: Forward=19, Left-Turn=2991, Right-Turn=2990 Steps=6000
# 🎯 Episode 1688 finished with reward 2739.14
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.72001443  0.74886112]
#    Gripper Position= [-1.30119114  0.4167148 ]
# 📊 Summary: Forward=337, Left-Turn=3203, Right-Turn=2460 Steps=6000
# 🎯 Episode 1689 finished with reward 2459.28
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 2.93630243 -0.86593915]
#    Gripper Position= [ 0.49567974 -0.41072476]
# 📊 Summary: Forward=78, Left-Turn=2926, Right-Turn=2996 Steps=6000
# 🎯 Episode 1690 finished with reward 2760.42
# ✅ Goal reached!
#    Goal Position   = [0.43613806 0.44719564]
#    Gripper Position= [0.41694796 0.40107284]
# 📊 Summary: Forward=2, Left-Turn=2407, Right-Turn=2166 Steps=4575
# 🎯 Episode 1691 finished with reward 2102.28
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [3.30772416 3.87354804]
#    Gripper Position= [0.6659847  0.58809992]
# 📊 Summary: Forward=278, Left-Turn=2896, Right-Turn=2826 Steps=6000
# 🎯 Episode 1692 finished with reward 2710.06
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 0.42176871 -3.95983027]
#    Gripper Position= [ 0.16644269 -1.44592431]
# 📊 Summary: Forward=426, Left-Turn=2768, Right-Turn=2806 Steps=6000
# 🎯 Episode 1693 finished with reward 2764.59
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 3.95087465 -3.5017093 ]
#    Gripper Position= [ 0.86369302 -1.08398783]
# 📊 Summary: Forward=372, Left-Turn=2784, Right-Turn=2844 Steps=6000
# 🎯 Episode 1694 finished with reward 2702.30
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.3966991   3.76271834]
#    Gripper Position= [-0.86771391  0.78677856]
# 📊 Summary: Forward=503, Left-Turn=2932, Right-Turn=2565 Steps=6000
# 🎯 Episode 1695 finished with reward 2495.41
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.46447866  1.04186321]
#    Gripper Position= [-0.7865923   0.40965047]
# 📊 Summary: Forward=36, Left-Turn=3194, Right-Turn=2770 Steps=6000
# 🎯 Episode 1696 finished with reward 2384.74
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [ 0.06447144 -1.51923916]
#    Gripper Position= [ 0.00805581 -0.51817241]
# 📊 Summary: Forward=4, Left-Turn=2942, Right-Turn=3054 Steps=6000
# 🎯 Episode 1697 finished with reward 2720.16
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.05253253 -3.39202677]
#    Gripper Position= [-0.64939042 -0.97154339]
# 📊 Summary: Forward=49, Left-Turn=2886, Right-Turn=3065 Steps=6000
# 🎯 Episode 1698 finished with reward 2768.60
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-1.38434592 -2.65958882]
#    Gripper Position= [-0.6067184  -0.99146404]
# 📊 Summary: Forward=22, Left-Turn=2910, Right-Turn=3068 Steps=6000
# 🎯 Episode 1699 finished with reward 2750.45
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-0.31615127  3.70930406]
#    Gripper Position= [-0.08713507  0.31250353]
# 📊 Summary: Forward=16, Left-Turn=3164, Right-Turn=2820 Steps=6000
# 🎯 Episode 1700 finished with reward 2588.34
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.94211663 -1.39093205]
#    Gripper Position= [ 0.36917164 -0.56086339]
# 📊 Summary: Forward=6, Left-Turn=2951, Right-Turn=3043 Steps=6000
# 🎯 Episode 1701 finished with reward 2688.37
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [3.68680112 2.02912064]
#    Gripper Position= [0.33386622 0.12938092]
# 📊 Summary: Forward=7, Left-Turn=3030, Right-Turn=2963 Steps=6000
# 🎯 Episode 1702 finished with reward 2729.41
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.58718896 -0.78802267]
#    Gripper Position= [-0.21932574 -0.23265982]
# 📊 Summary: Forward=8, Left-Turn=2919, Right-Turn=3073 Steps=6000
# 🎯 Episode 1703 finished with reward 2759.39
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [0.92360987 1.38673676]
#    Gripper Position= [0.47202887 0.45914004]
# 📊 Summary: Forward=8, Left-Turn=3046, Right-Turn=2946 Steps=6000
# 🎯 Episode 1704 finished with reward 2682.50
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.13373817  2.11947116]
#    Gripper Position= [-0.47539482  0.31893712]
# 📊 Summary: Forward=105, Left-Turn=3105, Right-Turn=2790 Steps=6000
# 🎯 Episode 1705 finished with reward 2493.54
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [ 0.72784456 -0.23157117]
#    Gripper Position= [ 0.10256493 -0.20854269]
# 📊 Summary: Forward=24, Left-Turn=2929, Right-Turn=3047 Steps=6000
# 🎯 Episode 1706 finished with reward 2740.29
# ⏳ Timeout. Reward=-49.85
#    Goal Position   = [-2.54277698 -0.11936718]
#    Gripper Position= [-0.69953994 -0.14343315]
# 📊 Summary: Forward=159, Left-Turn=3102, Right-Turn=2739 Steps=6000
# 🎯 Episode 1707 finished with reward 2373.03
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [0.79733894 1.07187418]
#    Gripper Position= [0.57229905 0.60132236]
# 📊 Summary: Forward=12, Left-Turn=3052, Right-Turn=2936 Steps=6000
# 🎯 Episode 1708 finished with reward 2655.72
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 3.07738527 -3.78000737]
#    Gripper Position= [ 0.31638722 -0.57496817]
# 📊 Summary: Forward=78, Left-Turn=2932, Right-Turn=2990 Steps=6000
# 🎯 Episode 1709 finished with reward 2698.16
# ⏳ Timeout. Reward=-49.25
#    Goal Position   = [ 0.77929181 -1.47367227]
#    Gripper Position= [ 0.27206555 -0.57874482]
# 📊 Summary: Forward=20, Left-Turn=2978, Right-Turn=3002 Steps=6000
# 🎯 Episode 1710 finished with reward 2747.01
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.78340317 -0.48964567]
#    Gripper Position= [-0.21662994 -0.2197378 ]
# 📊 Summary: Forward=146, Left-Turn=2811, Right-Turn=3043 Steps=6000
# 🎯 Episode 1711 finished with reward 2695.25
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [0.17504504 2.47483364]
#    Gripper Position= [0.08017487 0.5183962 ]
# 📊 Summary: Forward=17, Left-Turn=3033, Right-Turn=2950 Steps=6000
# 🎯 Episode 1712 finished with reward 2506.50
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-2.00518892 -3.92448428]
#    Gripper Position= [-0.85575765 -1.51172998]
# 📊 Summary: Forward=271, Left-Turn=2845, Right-Turn=2884 Steps=6000
# 🎯 Episode 1713 finished with reward 2791.02
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [1.48689686 3.08466205]
#    Gripper Position= [0.42048279 0.42394784]
# 📊 Summary: Forward=58, Left-Turn=3047, Right-Turn=2895 Steps=6000
# 🎯 Episode 1714 finished with reward 2702.95
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.15974193  2.92988357]
#    Gripper Position= [-0.65786745  0.53464962]
# 📊 Summary: Forward=220, Left-Turn=3078, Right-Turn=2702 Steps=6000
# 🎯 Episode 1715 finished with reward 2484.75
# ⏳ Timeout. Reward=-49.23
#    Goal Position   = [-1.92038439 -3.07133171]
#    Gripper Position= [-1.30136175 -2.05533541]
# 📊 Summary: Forward=484, Left-Turn=2802, Right-Turn=2714 Steps=6000
# 🎯 Episode 1716 finished with reward 2762.82
# ⏳ Timeout. Reward=-49.53
#    Goal Position   = [-3.48300809 -3.82916919]
#    Gripper Position= [-2.08549204 -2.53501962]
# 📊 Summary: Forward=891, Left-Turn=2578, Right-Turn=2531 Steps=6000
# 🎯 Episode 1717 finished with reward 2741.82
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [-3.35243639 -0.57443957]
#    Gripper Position= [-0.31507303 -0.24872992]
# 📊 Summary: Forward=189, Left-Turn=2817, Right-Turn=2994 Steps=6000
# 🎯 Episode 1718 finished with reward 2732.35
# ⏳ Timeout. Reward=-49.24
#    Goal Position   = [ 1.90200244 -3.2102348 ]
#    Gripper Position= [ 0.33502993 -0.64811428]
# 📊 Summary: Forward=52, Left-Turn=2919, Right-Turn=3029 Steps=6000
# 🎯 Episode 1719 finished with reward 2726.04
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-2.32534419  3.70815641]
#    Gripper Position= [-0.33944948  0.27759628]
# 📊 Summary: Forward=163, Left-Turn=3032, Right-Turn=2805 Steps=6000
# 🎯 Episode 1720 finished with reward 2507.99
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-0.88245156 -1.11090224]
#    Gripper Position= [-0.66265613 -0.84122108]
# 📊 Summary: Forward=35, Left-Turn=2820, Right-Turn=3145 Steps=6000
# 🎯 Episode 1721 finished with reward 2740.19
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.88892668  0.81955043]
#    Gripper Position= [-1.06611324  0.24428888]
# 📊 Summary: Forward=79, Left-Turn=3171, Right-Turn=2750 Steps=6000
# 🎯 Episode 1722 finished with reward 2464.46
# ⏳ Timeout. Reward=-49.84
#    Goal Position   = [-3.77220257 -2.89497697]
#    Gripper Position= [-0.79415206 -0.88457695]
# 📊 Summary: Forward=220, Left-Turn=2719, Right-Turn=3061 Steps=6000
# 🎯 Episode 1723 finished with reward 2760.94
# ✅ Model saved as stage1_nav.zip

# %%
#testing code 
import pybullet as p
import pybullet_data
import time
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback


# ---------------- Custom Gym Environment ----------------
class RobotEnv(gym.Env):
    def __init__(self, render=True):
        super(RobotEnv, self).__init__()
        
        self.render = render
        if self.render:
            p.connect(p.GUI)
        else:
            p.connect(p.DIRECT)

        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        p.setGravity(0, 0, -9.81)
        
        # Load environment
        self.plane = p.loadURDF("plane.urdf")
        self.robot = p.loadURDF("ryres.urdf", [0, 0, 0], useFixedBase=False,
                                flags=p.URDF_USE_SELF_COLLISION)
        
        # Wheels
        self.wheel_links = [9, 10, 12]   # tyre links
        for link in self.wheel_links:
            p.changeDynamics(self.robot, link,
                     lateralFriction=0.2,
                     spinningFriction=0.5,
                     rollingFriction=0.01)
            
        self.wheel_joints = [7, 8]   # drive joints
        self.max_force = 50.0
        self.max_speed = 20.0
        
        # ✅ Action space: [forward_speed (0..1), turn_rate (-1..1)]
        # self.action_space = spaces.Box(low=np.array([0.0, -1.0]), 
        #                                high=np.array([2.0, 1.0]),
        #                                dtype=np.float32)
        self.action_space = spaces.Discrete(3)  # 0=forward, 1=left, 2=right
        
        # Observation space
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4,), dtype=np.float32)
        
        # Episode settings
        self.max_steps = 10000
        self.current_step = 0
        self.goal_threshold = 0.05
        
        # Visual marker for goal
        self.goal_vis_id = None
        # ✅ Counters
        self.prev_dist = None 
        self.forward_count = 0
        self.left_turn_count = 0
        self.right_turn_count=0
        self.total_steps = 0

    def reset(self, seed=None, options=None):
        self.current_step = 0
        self.forward_count = 0
        self.left_turn_count = 0
        self.right_turn_count=0
        self.total_steps = 0
        # print("🔄 Counters reset.")
        # self.current_step = 0
        # Reset robot
        p.resetBasePositionAndOrientation(self.robot, [0, 0, 0.125], [0, 0, 0, 1])
        

        for i in range(p.getNumJoints(self.robot)):
            p.resetJointState(self.robot, i, 0)

        # Disable drive wheel motors
        for j in [7, 8]:  
            p.setJointMotorControl2(self.robot, j, p.VELOCITY_CONTROL,
                            targetVelocity=0, force=0)

        # Lock other joints
        for i in range(p.getNumJoints(self.robot)):
            if i not in [7, 8]:
                p.setJointMotorControl2(self.robot, i, p.VELOCITY_CONTROL,
                                targetVelocity=0, force=self.max_force)

        # Random goal
        self.goal = np.random.uniform(-3.5, 3.5, size=2)
        goal_pos = [self.goal[0], self.goal[1], 0.1]

        if self.goal_vis_id is not None:
            p.removeBody(self.goal_vis_id)

        vis_shape = p.createVisualShape(p.GEOM_SPHERE, radius=0.1, rgbaColor=[1, 0, 0, 1])
        col_shape = p.createCollisionShape(p.GEOM_SPHERE, radius=0.001)
        self.goal_vis_id = p.createMultiBody(baseMass=0,
                                            baseVisualShapeIndex=vis_shape,
                                            baseCollisionShapeIndex=col_shape,
                                            basePosition=goal_pos)
        
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        self.prev_dist = np.linalg.norm(np.array(gripper_pos[:2]) - self.goal)
        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2] - np.pi/2
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        goal_angle = np.arctan2(self.goal[1]-gripper_xy[1], self.goal[0]-gripper_xy[0])
        self.prev_heading_error = abs((goal_angle - yaw + np.pi) % (2*np.pi) - np.pi)


        return self._get_obs(), {}
    ##################################################################
    def step(self, action):
    # Map discrete actions to wheel speeds
        if action == 0:  # Forward
            left_vel = self.max_speed
            right_vel = self.max_speed
            self.forward_count += 1

        elif action == 1:  # Turn left
            left_vel = -0.5 * self.max_speed
            right_vel =  0.5 * self.max_speed
            self.left_turn_count += 1

        elif action == 2:  # Turn right
            left_vel =  0.5 * self.max_speed
            right_vel = -0.5 * self.max_speed
            self.right_turn_count += 1

    # Apply motor control
        p.setJointMotorControl2(self.robot, 7, p.VELOCITY_CONTROL,
                                targetVelocity=left_vel, force=self.max_force)
        p.setJointMotorControl2(self.robot, 8, p.VELOCITY_CONTROL,
                                targetVelocity=right_vel, force=self.max_force)

        p.stepSimulation()
        self.current_step += 1
        self.total_steps += 1

    # --- rest of your reward, obs, done logic stays same ---
        obs = self._get_obs()
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        dist_to_goal = np.linalg.norm(gripper_xy - self.goal)

        progress = self.prev_dist - dist_to_goal
        self.prev_dist = dist_to_goal

        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2] - np.pi/2   # align with -Y front
        goal_angle = np.arctan2(self.goal[1]-gripper_xy[1], self.goal[0]-gripper_xy[0])
        heading_error = abs((goal_angle - yaw + np.pi) % (2*np.pi) - np.pi)
        

        # reward = 0.0
        # reward += progress * 10.0
        # reward += np.cos(heading_error) * 0.5 
        # reward -= 0.01
        # --- Reward shaping ---
        reward = 0.0

        # Distance progress reward (main driver)
        reward += progress * 10.0  

        # Heading alignment reward (encourages facing goal)
        reward += np.cos(heading_error) * 0.5  

        # Penalize step cost slightly
        reward -= 0.045

        # ✅ Turning purposefully: only reward if it reduces heading error
        if action in [1, 2]:  # turn left or right
            if heading_error < self.prev_heading_error:  
                reward += 0.3   # good turn (aligning to goal)
            else:
                reward -= 0.3   # bad turn (misaligned more)

    #Save heading error for next step comparison
        self.prev_heading_error = heading_error

        done, truncated = False, False
        if dist_to_goal < self.goal_threshold:
            reward += 100
            done = True
            print(f"✅ Goal reached!")
            print(f"   Goal Position   = {self.goal}")
            print(f"   Gripper Position= {gripper_xy}")
            print(f"📊 Summary: Forward={self.forward_count}, Left-Turn={self.left_turn_count}, Right-Turn={self.right_turn_count} Steps={self.total_steps}")
        elif self.current_step >= self.max_steps:
            reward -= 50
            truncated = True
            print(f"⏳ Timeout. Reward={reward:.2f}")
            print(f"   Goal Position   = {self.goal}")
            print(f"   Gripper Position= {gripper_xy}")
            print(f"📊 Summary: Forward={self.forward_count}, Left-Turn={self.left_turn_count}, Right-Turn={self.right_turn_count} Steps={self.total_steps}")
    
        return obs, reward, done, truncated, {}

    def _get_obs(self):
        gripper_pos, _ = p.getLinkState(self.robot, 4)[:2]
        gripper_xy = np.array(gripper_pos[:2])
        _, base_orn = p.getBasePositionAndOrientation(self.robot)
        yaw = p.getEulerFromQuaternion(base_orn)[2]

        goal_vec = self.goal - gripper_xy
        dist = np.linalg.norm(goal_vec)
        angle = np.arctan2(goal_vec[1], goal_vec[0]) - yaw
        angle = (angle + np.pi) % (2 * np.pi) - np.pi
        
        return np.array([gripper_xy[0], gripper_xy[1], dist, angle], dtype=np.float32)

    def close(self):
        p.disconnect()


# ---------------- Callback for tracking episodes ----------------
class EpisodeTracker(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.episode_num = 0
        self.episode_reward = 0

    def _on_step(self) -> bool:
        reward = self.locals["rewards"][0]
        done = self.locals["dones"][0]
        self.episode_reward += reward

        if done:
            self.episode_num += 1
            print(f"🎯 Episode {self.episode_num} finished with reward {self.episode_reward:.2f}")
            self.episode_rewards.append(self.episode_reward)
            self.episode_reward = 0
        return True


# ---------------- Training ----------------
def train():
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")
    
    env = DummyVecEnv([lambda: RobotEnv(render=False)])
    callback = EpisodeTracker()
    
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=512,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.0,
        vf_coef=0.5,
        max_grad_norm=0.5,
        verbose=0,
        device=device,
    )
    
    model.learn(total_timesteps=5000_000, callback=callback)
    model.save("stage1_nav.zip")
    print("✅ Model saved as stage1_nav.zip")


# ---------------- Testing ----------------
def test():
    env = RobotEnv(render=True)
    model = PPO.load("stage1_nav.zip")
    
    obs, _ = env.reset()
    done, truncated = False, False
    total_reward = 0
    while not (done or truncated):
        action, _ = model.predict(obs)
        obs, reward, done, truncated, _ = env.step(action)
        total_reward += reward
        time.sleep(0.01)
    print(f"Episode finished with total reward = {total_reward:.2f}")
    env.close()


if __name__ == "__main__":
    # train()
    test()
# Out:
# ✅ Goal reached!
#    Goal Position   = [-0.9938412   0.02388495]
#    Gripper Position= [-0.94644331  0.03758538]
# 📊 Summary: Forward=318, Left-Turn=770, Right-Turn=0 Steps=1088
# Episode finished with total reward = 260.78
